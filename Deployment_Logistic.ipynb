# %%
import pickle
loaded_model = pickle.load(open("finalized_model_Logistic.sav",'rb'))
result = loaded_model.predict([[34,1102,1,5993,19479,8,2,4,5]])

# %%
result
# Out:
# array([1])
